# %%
from bs_fdbck.util.imports import import_fields_xr_v2
from bs_fdbck.util.imports.get_fld_fixed import get_field_fixed
# Out:
# /proj/bolinc/users/x_sarbl/analysis/BS-FDBCK/bs_fdbck/data_info/area_defs.csv

# %%
import useful_scit.util.log as log

log.ger.setLevel(log.log.INFO)

# %%
case_name='OsloAero_intBVOC_f09_f09_mg17_full'
st_time ='2012-01'
end_time = '2015-01'
varl = ['SFmonoterp','SFisoprene', 'Z3']

# %%
ds = import_fields_xr_v2.xr_import_NorESM(case_name, varl, st_time, end_time, )
# Out:
# 2022-09-29 13:47:09,472 useful_scit  INFO     Path file list:
# 2022-09-29 13:47:09,472 useful_scit  INFO     Path file list:
# ...

# %%
dummy = get_field_fixed(case_name,
                                varl,
                                st_time, end_time,
                                #raw_data_path=raw_data_path,
                                pressure_adjust=False
                       )
# Out:
# 2022-09-29 14:06:48,860 useful_scit  INFO     Path file list:
# 2022-09-29 14:06:48,860 useful_scit  INFO     Path file list:
# ...

# %%
from bs_fdbck.util.plot import plot_maps

# %%
ds = dummy

# %%
import cartopy.crs as ccrs
import matplotlib.path as mpath
import numpy as np

# %%
fig, ax = plot_maps.subplots_map(subplot_kw = dict(projection=ccrs.NorthPolarStereo()))


theta = np.linspace(0, 2*np.pi, 100)
map_circle = mpath.Path(np.vstack([np.sin(theta), np.cos(theta)]).T * 0.5 + [0.5, 0.5])
ax.set_boundary(map_circle, transform=ax.transAxes)
da = ds['SFisoprene'].mean('time')
da = da.where(da.lat>50)
plot_maps.plt_map(da, ax =ax, cmap = 'Reds')
ax.set_extent([-180, 180, 60,90], ccrs.PlateCarree())
ax.coastlines(linewidth = .1);
ax.gridlines();
# Out:
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/cartopy/mpl/gridliner.py:307: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/cartopy/mpl/gridliner.py:331: UserWarning: The .ylabels_left attribute is deprecated. Please use .left_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_left attribute is deprecated. Please '
