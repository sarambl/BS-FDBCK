# %%
import xarray as xr

# %%
lat_smr = 61.85
lon_smr = 24.28

# %%
fn1 = '/proj/bolinc/users/x_sarbl/noresm_archive/OsloAero_intBVOC_f19_f19_mg17_full/atm/hist/OsloAero_intBVOC_f19_f19_mg17_full.cam.h0.2012-06.nc'
fn2 = '/proj/bolinc/users/x_sarbl/noresm_archive/OsloAero_intBVOC_pertSizeDist2_f19_f19_mg17_full/atm/hist/OsloAero_intBVOC_pertSizeDist2_f19_f19_mg17_full.cam.h0.2012-06.nc'
fn3 = '/proj/bolinc/users/x_sarbl/noresm_archive/OsloAero_intBVOC_pertSizeDist_f19_f19_mg17_full/atm/hist/OsloAero_intBVOC_pertSizeDist_f19_f19_mg17_full.cam.h0.2012-06.nc'

# %%
ds1 = xr.open_dataset(fn1)

# %%
ds2= xr.open_dataset(fn2)

# %%
ds3= xr.open_dataset(fn3)

# %%
ds1['NCONC01'].isel(lev=-1).plot(vmin=0, vmax=.9e10)

# %%
ds2['NCONC01'].isel(lev=-1).plot(vmin=0, vmax=.9e10)

# %%
ds3['NCONC01'].isel(lev=-1).plot(vmin=0, vmax=.9e10)

# %%
import matplotlib.pyplot as plt

# %%
for i, ds in enumerate([ds1,ds2,ds3]):
    
    ds['NCONC04'].sel(lat = lat_smr, lon=lon_smr, method='nearest').plot(marker='*', label =i )#robust=True)
    #plt.show()
plt.legend()
#vmin=0, vmax=.11e10)

# %%
for i, ds in enumerate([ds1,ds2,ds3]):
    
    ds['NCONC05'].sel(lat = lat_smr, lon=lon_smr, method='nearest').plot(marker='*', label =i )#robust=True)
    #plt.show()
plt.legend()
#vmin=0, vmax=.11e10)

# %%
for i, ds in enumerate([ds1,ds2,ds3]):
    
    ds['NCONC01'].sel(lat = lat_smr, lon=lon_smr, method='nearest').plot(marker='*', label =i )#robust=True)
    #plt.show()
plt.legend()
#vmin=0, vmax=.11e10)

# %%
for i, ds in enumerate([ds1,ds2,ds3]):
    
    ds['CCN1'].sel(lat = lat_smr, lon=lon_smr, method='nearest').plot(marker='*', label =i )#robust=True)
    #plt.show()
plt.legend()
#vmin=0, vmax=.11e10)

# %%
for i, ds in enumerate([ds1,ds2,ds3]):
    
    ds['NCONC04'].isel(lev=-1).plot(vmin=0, vmax=3.5e9)
    plt.show()
#plt.legend()
#vmin=0, vmax=.11e10)

# %%
ds2['NCONC06'].isel(lev=-1).plot(vmin=0, vmax=.9e10)

# %%
ds3['NCONC04'].isel(lev=-1).plot(vmin=0, vmax=.9e10)
