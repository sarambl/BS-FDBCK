# %%
import matplotlib.pyplot as plt

# %%
import xarray as xr

from pathlib import Path
from bs_fdbck_clean.constants import path_outdata

path_out = path_outdata /'NorESM_clm'

path_out.mkdir(exist_ok=True)
vs = [
    'PCT_NAT_PFT',
    'PCT_LANDUNIT',
    'PCT_CFT',
    'PFT_FIRE_CLOSS',
    'PFT_FIRE_NLOSS',
    'TLAI',
    'LAISUN',
    'LAISHA',
    'ELAI',
    'MEG_limonene',
    'MEG_sabinene',
    'MEG_pinene_b',
    'MEG_pinene_a',
    'MEG_ocimene_t_b',
    'MEG_myrcene',
    'MEG_isoprene',
    'MEG_carene_3',
    'H2OSOI',
    'QSOIL',
    'SOILLIQ',
    'SOILRESIS',
    'TOTSOILLIQ',
    
]

case_name= 'OsloAero_intBVOC_f09_f09_mg17_full'
_pa_out = path_out/case_name 
_pa_out.mkdir(exist_ok=True)
for y in range(2012,2015):
    print(y)
    f = f'/proj/bolinc/users/x_sarbl/noresm_archive/{case_name}/lnd/hist/{case_name}.clm2*{y}*'
    print(f)
    _ds = xr.open_mfdataset(f)

    f_out =   _pa_out / f'{case_name}.clm2.concat.{y}.nc'
    print(f'writing to {f_out}')
    _ds[vs].to_netcdf(f_out)


case_name= 'OsloAero_intBVOC_f09_f09_mg17_ssp245'
_pa_out = path_out/case_name 
_pa_out.mkdir(exist_ok=True)
for y in range(2015,2019):
    print(y)
    f = f'/proj/bolinc/users/x_sarbl/noresm_archive/{case_name}/lnd/hist/{case_name}.clm2*{y}*'
    print(f)
    _ds = xr.open_mfdataset(f)
    f_out =   _pa_out/ f'{case_name}.clm2.concat.{y}.nc'
    print(f'writing to {f_out}')
    _ds[vs].to_netcdf(f_out)
# Out:
# /proj/bolinc/users/x_sarbl/analysis/BS-FDBCK_clean/bs_fdbck_clean/data_info
# 2012
# /proj/bolinc/users/x_sarbl/noresm_archive/OsloAero_intBVOC_f09_f09_mg17_full/lnd/hist/OsloAero_intBVOC_f09_f09_mg17_full.clm2*2012*
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/backends/plugins.py:61: RuntimeWarning: Engine 'rasterio' loading failed:
# (click 8.0.1 (/home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages), Requirement.parse('click<8,>=4.0'), {'rasterio'})
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)
# writing to /proj/bolinc/users/x_sarbl/analysis/Output_data_BS-FDBCK/NorESM_clm/OsloAero_intBVOC_f09_f09_mg17_full/OsloAero_intBVOC_f09_f09_mg17_full.clm2.concat.2012.nc
# 2013
# /proj/bolinc/users/x_sarbl/noresm_archive/OsloAero_intBVOC_f09_f09_mg17_full/lnd/hist/OsloAero_intBVOC_f09_f09_mg17_full.clm2*2013*
# writing to /proj/bolinc/users/x_sarbl/analysis/Output_data_BS-FDBCK/NorESM_clm/OsloAero_intBVOC_f09_f09_mg17_full/OsloAero_intBVOC_f09_f09_mg17_full.clm2.concat.2013.nc
# 2014
# /proj/bolinc/users/x_sarbl/noresm_archive/OsloAero_intBVOC_f09_f09_mg17_full/lnd/hist/OsloAero_intBVOC_f09_f09_mg17_full.clm2*2014*
# writing to /proj/bolinc/users/x_sarbl/analysis/Output_data_BS-FDBCK/NorESM_clm/OsloAero_intBVOC_f09_f09_mg17_full/OsloAero_intBVOC_f09_f09_mg17_full.clm2.concat.2014.nc
# 2015
# /proj/bolinc/users/x_sarbl/noresm_archive/OsloAero_intBVOC_f09_f09_mg17_ssp245/lnd/hist/OsloAero_intBVOC_f09_f09_mg17_ssp245.clm2*2015*
# writing to /proj/bolinc/users/x_sarbl/analysis/Output_data_BS-FDBCK/NorESM_clm/OsloAero_intBVOC_f09_f09_mg17_ssp245/OsloAero_intBVOC_f09_f09_mg17_ssp245.clm2.concat.2015.nc
# 2016
# /proj/bolinc/users/x_sarbl/noresm_archive/OsloAero_intBVOC_f09_f09_mg17_ssp245/lnd/hist/OsloAero_intBVOC_f09_f09_mg17_ssp245.clm2*2016*
# writing to /proj/bolinc/users/x_sarbl/analysis/Output_data_BS-FDBCK/NorESM_clm/OsloAero_intBVOC_f09_f09_mg17_ssp245/OsloAero_intBVOC_f09_f09_mg17_ssp245.clm2.concat.2016.nc
# 2017
# /proj/bolinc/users/x_sarbl/noresm_archive/OsloAero_intBVOC_f09_f09_mg17_ssp245/lnd/hist/OsloAero_intBVOC_f09_f09_mg17_ssp245.clm2*2017*
# writing to /proj/bolinc/users/x_sarbl/analysis/Output_data_BS-FDBCK/NorESM_clm/OsloAero_intBVOC_f09_f09_mg17_ssp245/OsloAero_intBVOC_f09_f09_mg17_ssp245.clm2.concat.2017.nc
# 2018
# /proj/bolinc/users/x_sarbl/noresm_archive/OsloAero_intBVOC_f09_f09_mg17_ssp245/lnd/hist/OsloAero_intBVOC_f09_f09_mg17_ssp245.clm2*2018*
# writing to /proj/bolinc/users/x_sarbl/analysis/Output_data_BS-FDBCK/NorESM_clm/OsloAero_intBVOC_f09_f09_mg17_ssp245/OsloAero_intBVOC_f09_f09_mg17_ssp245.clm2.concat.2018.nc

# %%
case_name= 'OsloAero_intBVOC_f09_f09_mg17_full'
_pa_out = path_out/case_name 
ds_clm_hist= xr.open_mfdataset(str(_pa_out)+'/*.nc')#/proj/bolinc/users/x_sarbl/noresm_archive/OsloAero_intBVOC_f09_f09_mg17_full/lnd/*.nc')

# %%
case_name= 'OsloAero_intBVOC_f09_f09_mg17_ssp245'

_pa_out = path_out/case_name 
ds_clm_ssp= xr.open_mfdataset(str(_pa_out)+'/*.nc')#/proj/bolinc/users/x_sarbl/noresm_archive/OsloAero_intBVOC_f09_f09_mg17_full/lnd/*.nc')

# %%
ds_clm_ssp
# Out:
# <xarray.Dataset>
# Dimensions:          (time: 48, natpft: 15, lat: 192, lon: 288, ltype: 9, cft: 64, levsoi: 20)
# Coordinates:
#   * time             (time) datetime64[ns] 2015-02-01 2015-03-01 ... 2019-01-01
#   * lon              (lon) float64 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
#   * lat              (lat) float64 -90.0 -89.06 -88.12 ... 88.12 89.06 90.0
# Dimensions without coordinates: natpft, ltype, cft, levsoi
# Data variables: (12/22)
#     PCT_NAT_PFT      (time, natpft, lat, lon) float64 dask.array<chunksize=(12, 15, 192, 288), meta=np.ndarray>
#     PCT_LANDUNIT     (time, ltype, lat, lon) float64 dask.array<chunksize=(12, 9, 192, 288), meta=np.ndarray>
#     PCT_CFT          (time, cft, lat, lon) float64 dask.array<chunksize=(12, 64, 192, 288), meta=np.ndarray>
#     PFT_FIRE_CLOSS   (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
#     PFT_FIRE_NLOSS   (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
#     TLAI             (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
#     ...               ...
#     MEG_carene_3     (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
#     H2OSOI           (time, levsoi, lat, lon) float64 dask.array<chunksize=(12, 20, 192, 288), meta=np.ndarray>
#     QSOIL            (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
#     SOILLIQ          (time, levsoi, lat, lon) float64 dask.array<chunksize=(12, 20, 192, 288), meta=np.ndarray>
#     SOILRESIS        (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
#     TOTSOILLIQ       (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
# Attributes: (12/100)
#     title:                                     CLM History file information
#     comment:                                   NOTE: None of the variables ar...
#     Conventions:                               CF-1.0
#     history:                                   created on 04/13/22 19:56:41
#     source:                                    Community Land Model CLM4.0
#     hostname:                                  tetralith
#     ...                                        ...
#     cft_irrigated_switchgrass:                 60
#     cft_tropical_corn:                         61
#     cft_irrigated_tropical_corn:               62
#     cft_tropical_soybean:                      63
#     cft_irrigated_tropical_soybean:            64
#     time_period_freq:                          month_1

# %%
ds_clm_hist['PCT_NAT_PFT'].sum('natpft').sel(lon=300.9, lat=-2.15, method='nearest').plot()
ds_clm_ssp['PCT_NAT_PFT'].sum('natpft').sel(lon=300.9, lat=-2.15, method='nearest').plot()
# Out:
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(

# %%
for i in range(15):
    ds_clm_hist['PCT_NAT_PFT'].isel(natpft=i).sel(lon=300.9, lat=-2.15, method='nearest').plot()
    ds_clm_ssp['PCT_NAT_PFT'].isel(natpft=i).sel(lon=300.9, lat=-2.15, method='nearest').plot()
    plt.title(i)
    plt.show()
# Out:
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(

# %%
ds_clm_hist
# Out:
# <xarray.Dataset>
# Dimensions:          (time: 36, natpft: 15, lat: 192, lon: 288, ltype: 9, cft: 64, levsoi: 20)
# Coordinates:
#   * time             (time) datetime64[ns] 2012-02-01 2012-03-01 ... 2015-01-01
#   * lon              (lon) float64 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
#   * lat              (lat) float64 -90.0 -89.06 -88.12 ... 88.12 89.06 90.0
# Dimensions without coordinates: natpft, ltype, cft, levsoi
# Data variables: (12/22)
#     PCT_NAT_PFT      (time, natpft, lat, lon) float64 dask.array<chunksize=(12, 15, 192, 288), meta=np.ndarray>
#     PCT_LANDUNIT     (time, ltype, lat, lon) float64 dask.array<chunksize=(12, 9, 192, 288), meta=np.ndarray>
#     PCT_CFT          (time, cft, lat, lon) float64 dask.array<chunksize=(12, 64, 192, 288), meta=np.ndarray>
#     PFT_FIRE_CLOSS   (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
#     PFT_FIRE_NLOSS   (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
#     TLAI             (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
#     ...               ...
#     MEG_carene_3     (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
#     H2OSOI           (time, levsoi, lat, lon) float64 dask.array<chunksize=(12, 20, 192, 288), meta=np.ndarray>
#     QSOIL            (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
#     SOILLIQ          (time, levsoi, lat, lon) float64 dask.array<chunksize=(12, 20, 192, 288), meta=np.ndarray>
#     SOILRESIS        (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
#     TOTSOILLIQ       (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
# Attributes: (12/100)
#     title:                                     CLM History file information
#     comment:                                   NOTE: None of the variables ar...
#     Conventions:                               CF-1.0
#     history:                                   created on 03/30/22 03:22:06
#     source:                                    Community Land Model CLM4.0
#     hostname:                                  tetralith
#     ...                                        ...
#     cft_irrigated_switchgrass:                 60
#     cft_tropical_corn:                         61
#     cft_irrigated_tropical_corn:               62
#     cft_tropical_soybean:                      63
#     cft_irrigated_tropical_soybean:            64
#     time_period_freq:                          month_1

# %%
ds_clm_hist['TLAI'].sel(lon=300.9, lat=-2.15, method='nearest').plot()
ds_clm_ssp['TLAI'].sel(lon=300.9, lat=-2.15, method='nearest').plot()
plt.show()
# Out:
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(

# %%
ds_clm_hist['QSOIL'].sel(lon=300.9, lat=-2.15, method='nearest').plot()
ds_clm_ssp['QSOIL'].sel(lon=300.9, lat=-2.15, method='nearest').plot()
#plt.title(i)
plt.show()
# Out:
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(

# %%
vl = ['SOILRESIS','PFT_FIRE_CLOSS','PFT_FIRE_NLOSS','LAISUN','TLAI','ELAI','TOTSOILLIQ']
for v in vl:
    ds_clm_hist[v].sel(lon=300.9, lat=-2.15, method='nearest').plot()
    ds_clm_ssp[v].sel(lon=300.9, lat=-2.15, method='nearest').plot()
    plt.title(v)
    plt.show()
# Out:
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(

# %%
ds_clm_hist
# Out:
# <xarray.Dataset>
# Dimensions:          (time: 36, natpft: 15, lat: 192, lon: 288, ltype: 9, cft: 64, levsoi: 20)
# Coordinates:
#   * time             (time) datetime64[ns] 2012-02-01 2012-03-01 ... 2015-01-01
#   * lon              (lon) float64 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
#   * lat              (lat) float64 -90.0 -89.06 -88.12 ... 88.12 89.06 90.0
# Dimensions without coordinates: natpft, ltype, cft, levsoi
# Data variables: (12/22)
#     PCT_NAT_PFT      (time, natpft, lat, lon) float64 dask.array<chunksize=(12, 15, 192, 288), meta=np.ndarray>
#     PCT_LANDUNIT     (time, ltype, lat, lon) float64 dask.array<chunksize=(12, 9, 192, 288), meta=np.ndarray>
#     PCT_CFT          (time, cft, lat, lon) float64 dask.array<chunksize=(12, 64, 192, 288), meta=np.ndarray>
#     PFT_FIRE_CLOSS   (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
#     PFT_FIRE_NLOSS   (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
#     TLAI             (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
#     ...               ...
#     MEG_carene_3     (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
#     H2OSOI           (time, levsoi, lat, lon) float64 dask.array<chunksize=(12, 20, 192, 288), meta=np.ndarray>
#     QSOIL            (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
#     SOILLIQ          (time, levsoi, lat, lon) float64 dask.array<chunksize=(12, 20, 192, 288), meta=np.ndarray>
#     SOILRESIS        (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
#     TOTSOILLIQ       (time, lat, lon) float64 dask.array<chunksize=(12, 192, 288), meta=np.ndarray>
# Attributes: (12/100)
#     title:                                     CLM History file information
#     comment:                                   NOTE: None of the variables ar...
#     Conventions:                               CF-1.0
#     history:                                   created on 03/30/22 03:22:06
#     source:                                    Community Land Model CLM4.0
#     hostname:                                  tetralith
#     ...                                        ...
#     cft_irrigated_switchgrass:                 60
#     cft_tropical_corn:                         61
#     cft_irrigated_tropical_corn:               62
#     cft_tropical_soybean:                      63
#     cft_irrigated_tropical_soybean:            64
#     time_period_freq:                          month_1

# %%
for i in range(9):
    ds_clm_hist['PCT_LANDUNIT'].isel(ltype=i).sel(lon=300.9, lat=-2.15, method='nearest').plot()
    ds_clm_ssp['PCT_LANDUNIT'].isel(ltype=i).sel(lon=300.9, lat=-2.15, method='nearest').plot()
    plt.title(i)
    plt.show()
# Out:
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(
# /home/x_sarbl/miniconda3/envs/env_analys/lib/python3.8/site-packages/xarray/core/indexes.py:224: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = index.get_loc(

# %%
f = '/proj/bolinc/users/x_sarbl/noresm_input_data/ems_OsloAero_intBVOC_f09_f09_mg17_fssp_2012-2018_SFisoprene_addleapyear.nc'

# %%
_ds = xr.open_dataset(f)

# %%
_ds['datesec'].plot(linewidth=0, marker='.')

# %%
f2 = '/proj/bolinc/users/x_sarbl/noresm_input_data/ems_OsloAero_intBVOC_f19_f19_mg17_ssp245_2015-2016_SFmonoterp_addleapyear.nc'

# %%
_ds2 = xr.open_dataset(f2)

# %%
_ds2['datesec'].plot(linewidth=0, marker='.')
_ds['datesec'].plot(linewidth=0, marker='.')
plt.ylim([4000,8000])
# Out:
# (4000.0, 8000.0)

# %%
_ds2['datesec'].drop_duplicates
# Out:
# <xarray.DataArray 'datesec' (time: 17569)>
# array([    0,  1800,  3600, ..., 81000, 82800, 84600], dtype=int32)
# Coordinates:
#   * time     (time) datetime64[ns] 2000-01-01 ... 2000-12-31T23:30:00
# Attributes:
#     long_name:  current seconds of current date

# %%
plt.scatter(_ds['datesec'], _ds2['datesec'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_56010/2231360886.py in <module>
# ----> 1 plt.scatter(_ds['datesec'], _ds2['datesec'])
#
# ~/miniconda3/envs/env_analys/lib/python3.8/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3066         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    3067         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 3068     __ret = gca().scatter(
#    3069         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    3070         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~/miniconda3/envs/env_analys/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/miniconda3/envs/env_analys/lib/python3.8/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4496         y = np.ma.ravel(y)
#    4497         if x.size != y.size:
# -> 4498             raise ValueError("x and y must be the same size")
#    4499
#    4500         if s is None:
#
# ValueError: x and y must be the same size
